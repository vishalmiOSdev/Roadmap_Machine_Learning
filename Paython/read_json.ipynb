# %%
import pandas as pd
pd.read_json('employe.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 pd.read_json('employe.json',usecols=["department"])
#
# TypeError: read_json() got an unexpected keyword argument 'usecols'
